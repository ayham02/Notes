# %%
import numpy as np
np.random.seed(2)

x = np.arange(0,5,0.01)
y = np.poly1d([0.5,2,-4,-1,-50])
y = y(x) + 50 * np.random.randn(len(x))

# %%
"""
split data into train and test
"""
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)

# %%
x_train_reshape = x_train.reshape(-1,1)
x_test_reshape = x_test.reshape(-1,1)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly1 = PolynomialFeatures(degree = 1, include_bias = False)
transformed = poly1.fit_transform(x_train_reshape)
transformed
# Out:
# array([[3.28],
#        [1.61],
#        [3.72],
#        [0.52],
#        [2.68],
#        [2.09],
#        [1.8 ],
#        [0.19],
#        [0.46],
#        [3.86],
#        [2.11],
#        [0.7 ],
#        [4.29],
#        [4.12],
#        [0.97],
#        [3.9 ],
#        [4.71],
#        [0.2 ],
#        [2.56],
#        [1.84],
#        [1.  ],
#        [2.53],
#        [3.65],
#        [0.44],
#        [1.5 ],
#        [1.99],
#        [0.63],
#        [2.59],
#        [3.7 ],
#        [2.62],
#        [4.91],
#        [2.26],
#        [2.19],
#        [1.65],
#        [1.52],
#        [1.81],
#        [2.35],
#        [4.65],
#        [1.13],
#        [3.32],
#        [0.07],
#        [4.61],
#        [4.66],
#        [3.13],
#        [3.3 ],
#        [4.54],
#        [1.83],
#        [4.  ],
#        [0.47],
#        [2.16],
#        [1.07],
#        [1.31],
#        [2.12],
#        [3.99],
#        [3.93],
#        [0.34],
#        [0.21],
#        [0.61],
# ...
